# %% [markdown]
# # Homework 7: 3,6,9

# %% [markdown]
# ## Polynomial Degree Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from ISLP import load_data

from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_val_score

from statsmodels.stats.anova import anova_lm
import statsmodels.api as sm

# %%
wage = load_data("wage")

# %%
wage.head()
# Out:
#    year  age            maritl      race        education              region  \
# 0  2006   18  1. Never Married  1. White     1. < HS Grad  2. Middle Atlantic
# 1  2004   24  1. Never Married  1. White  4. College Grad  2. Middle Atlantic
# 2  2003   45        2. Married  1. White  3. Some College  2. Middle Atlantic
# 3  2003   43        2. Married  3. Asian  4. College Grad  2. Middle Atlantic
# 4  2005   50       4. Divorced  1. White       2. HS Grad  2. Middle Atlantic
#
#          jobclass          health health_ins   logwage        wage
# 0   1. Industrial       1. <=Good      2. No  4.318063   75.043154
# 1  2. Information  2. >=Very Good      2. No  4.255273   70.476020
# 2   1. Industrial       1. <=Good     1. Yes  4.875061  130.982177
# 3  2. Information  2. >=Very Good     1. Yes  5.041393  154.685293
# 4  2. Information       1. <=Good     1. Yes  4.318063   75.043154

# %%
wage.shape
# Out:
# (3000, 11)

# %% [markdown]
# ## Exercice 3

# %% [markdown]
# ## Cross Validation Technique

# %%
X =  wage[['age']]
y = wage['wage']

# %%
X.head( )
# Out:
#    age
# 0   18
# 1   24
# 2   45
# 3   43
# 4   50

# %%
degrees = range(1, 11)
cv_errors = []

for i in degrees:
    poly = PolynomialFeatures(degree=i)
    X_poly = poly.fit_transform(X)
    
    model = LinearRegression()
    mse = -cross_val_score(model, X_poly, y, cv=10, scoring='neg_mean_squared_error').mean()
    cv_errors.append(mse)

# %%
model
# Out:
# LinearRegression()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Find the best degree
best_degree = degrees[np.argmin(cv_errors)]

# Plot
plt.figure(figsize=(8, 6))
plt.plot(degrees, cv_errors, marker='o', label='CV MSE')
plt.axvline(x=best_degree, color='red', linestyle='--', label=f'Best Degree = {best_degree}')
plt.scatter(best_degree, min(cv_errors), color='red', zorder=5)
plt.xlabel('Polynomial Degree')
plt.ylabel('10-Fold Cross-Validated MSE')
plt.title('Selecting Polynomial Degree via Cross-Validation')
plt.legend()
plt.grid(True)
plt.show()

# %%
best_degree = degrees[np.argmin(cv_errors)]
print(f"The best polynomial degree based on cross-validated MSE is: {best_degree}")
# Out:
# The best polynomial degree based on cross-validated MSE is: 8

# %% [markdown]
# ## ANOVA PART

# %%
models = []
for d in degrees:
    poly = PolynomialFeatures(degree=d, include_bias=False)
    X_poly = poly.fit_transform(X)
    
    X_poly  = sm.add_constant(X_poly)
    model = sm.OLS(y, X_poly).fit()
    models.append(model)

# %%
models[2].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                   wage   R-squared:                       0.085
# Model:                            OLS   Adj. R-squared:                  0.084
# Method:                 Least Squares   F-statistic:                     92.89
# Date:                Tue, 06 May 2025   Prob (F-statistic):           1.75e-57
# Time:                        20:39:43   Log-Likelihood:                -15316.
# No. Observations:                3000   AIC:                         3.064e+04
# Df Residuals:                    2996   BIC:                         3.066e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -75.2439     22.184     -3.392      0.001    -118.741     -31.747
# ...

# %%
## Step 2: Annova Analysis
annova_results = anova_lm(*models)

# %%
annova_results
# Out:
#    df_resid           ssr  df_diff        ss_diff           F        Pr(>F)
# 0    2998.0  5.022216e+06      0.0            NaN         NaN           NaN
# 1    2997.0  4.793430e+06      1.0  228786.010128  143.518660  2.449925e-32
# 2    2996.0  4.777674e+06      1.0   15755.693664    9.883629  1.683871e-03
# 3    2995.0  4.771604e+06      1.0    6070.152124    3.807838  5.110635e-02
# 4    2994.0  4.770322e+06      1.0    1282.563017    0.804558  3.698061e-01
# 5    2993.0  4.766389e+06      1.0    3932.257499    2.466726  1.163856e-01
# 6    2993.0  4.764599e+06     -0.0    1790.481752        -inf           NaN
# 7    2993.0  4.764136e+06     -0.0     462.460746        -inf           NaN
# 8    2993.0  4.764981e+06     -0.0    -844.190096         inf           NaN
# 9    2993.0  4.771202e+06     -0.0   -6221.386832         inf           NaN

# %%
import matplotlib.pyplot as plt

# Extract p-values from ANOVA results
p_values = annova_results["Pr(>F)"].dropna()  # Drop NaNs for plotting
anova_degrees = range(2, 2 + len(p_values))  # Degree comparison starts from 2

# Plot
plt.figure(figsize=(8, 6))
plt.plot(anova_degrees, p_values, marker='o', color='purple')
plt.axhline(y=0.05, color='red', linestyle='--', label='Significance Threshold (p=0.05)')
plt.xlabel('Polynomial Degree Being Added')
plt.ylabel('p-value from ANOVA F-test')
plt.title('ANOVA p-values for Added Polynomial Degrees')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercice 6: Step Function to Predict Wage

# %%
X
# Out:
#       age
# 0      18
# 1      24
# 2      45
# 3      43
# 4      50
# ...   ...
# 2995   44
# 2996   30
# 2997   27
# 2998   27
# 2999   55
#
# [3000 rows x 1 columns]

# %%
X.describe()
# Out:
#                age
# count  3000.000000
# mean     42.414667
# std      11.542406
# min      18.000000
# 25%      33.750000
# 50%      42.000000
# 75%      51.000000
# max      80.000000

# %%
cuts_range = range(2, 11)
cv_errors = []

for n_cuts in cuts_range:
    age_bins = pd.cut(X['age'], bins=n_cuts)
    X_step = pd.get_dummies(age_bins)
    
    model = LinearRegression()
    mse = -cross_val_score(model, X_step, y, scoring='neg_mean_squared_error', cv=10).mean()
    cv_errors.append(mse)

# Find optimal number of cuts
best_cuts = cuts_range[np.argmin(cv_errors)]
print("Best number of cuts:", best_cuts)
# Out:
# Best number of cuts: 8

# %%
# Refit using the best number of cuts
age_bins = pd.cut(X['age'], bins=best_cuts)
X_step = pd.get_dummies(age_bins)
model = LinearRegression().fit(X_step, y)

# Predict on age range
age_range = np.linspace(X['age'].min(), X['age'].max(), 500)
age_bin_pred = pd.cut(age_range, bins=best_cuts)
X_pred_step = pd.get_dummies(age_bin_pred)
X_pred_step = X_pred_step.reindex(columns=X_step.columns, fill_value=0)  # align columns
wage_pred = model.predict(X_pred_step)

# Plot
plt.figure(figsize=(10, 6))
plt.scatter(X['age'], y, color='lightgray', alpha=0.5, label='Observed Data')
plt.plot(age_range, wage_pred, color='green', linewidth=2, label=f'Step Function (cuts={best_cuts})')
plt.xlabel('Age')
plt.ylabel('Wage')
plt.title('Step Function Fit for Wage ~ Age')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Exercice 9:

# %%
df_boston =  load_data("Boston")

# %%
df_boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
df_boston['dis'].describe()
# Out:
# count    506.000000
# mean       3.795043
# std        2.105710
# min        1.129600
# 25%        2.100175
# 50%        3.207450
# 75%        5.188425
# max       12.126500
# Name: dis, dtype: float64

# %%
df_boston['nox'].describe()
# Out:
# count    506.000000
# mean       0.554695
# std        0.115878
# min        0.385000
# 25%        0.449000
# 50%        0.538000
# 75%        0.624000
# max        0.871000
# Name: nox, dtype: float64

# %% [markdown]
# ### a)

# %%
from ISLP.models import poly

# %%
X_boston = df_boston['dis']
y_boston = df_boston['nox']

# %%
X_boston.head()
# Out:
# 0    4.0900
# 1    4.9671
# 2    4.9671
# 3    6.0622
# 4    6.0622
# Name: dis, dtype: float64

# %%
X_boston.head()
# Out:
# 0    4.0900
# 1    4.9671
# 2    4.9671
# 3    6.0622
# 4    6.0622
# Name: dis, dtype: float64

# %%
poly_boston = PolynomialFeatures(degree=3, include_bias=False)
X_boston_poly = poly_boston.fit_transform(X_boston.values.reshape(-1, 1))
X_boston_poly.shape
# Out:
# (506, 3)

# %%
X_boston_poly
# Out:
# array([[  4.09      ,  16.7281    ,  68.417929  ],
#        [  4.9671    ,  24.67208241, 122.54870054],
#        [  4.9671    ,  24.67208241, 122.54870054],
#        ...,
#        [  2.1675    ,   4.69805625,  10.18303692],
#        [  2.3889    ,   5.70684321,  13.63307774],
#        [  2.505     ,   6.275025  ,  15.71893762]])

# %%
poly_boston
# Out:
# PolynomialFeatures(degree=3, include_bias=False)

# %%
X_boston_poly.shape
# Out:
# (506, 3)

# %%
model_boston = LinearRegression().fit(X_boston_poly, y_boston)

# %%
print(f"model_boston.coef_: {model_boston.coef_}")
print(f"model_boston.intercept_: {model_boston.intercept_}")
# Out:
# model_boston.coef_: [-0.18208169  0.02192766 -0.000885  ]
# model_boston.intercept_: 0.9341280720211862

# %%
y_pred_boston = model_boston.predict(X_boston_poly)

# %%
y_pred_boston[:2]
# Out:
# array([0.49567243, 0.462256  ])

# %%
import matplotlib.pyplot as plt
import numpy as np

# Step 1: Sort the predictor values for smooth curve
X_sorted = np.sort(X_boston.values.reshape(-1, 1), axis=0)
X_sorted_poly = poly_boston.transform(X_sorted)
y_sorted_pred = model_boston.predict(X_sorted_poly)

# Step 2: Plot
plt.figure(figsize=(8, 6))
plt.scatter(X_boston, y_boston, color='blue', alpha=0.6, label='Actual Data')
plt.plot(X_sorted, y_sorted_pred, color='red', linewidth=2, label='Cubic Fit')
plt.xlabel('dis (Distance to employment centers)')
plt.ylabel('nox (Nitrogen Oxides concentration)')
plt.title('Cubic Polynomial Regression: dis vs. nox')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## b)

# %%
X_boston.describe()
# Out:
# count    506.000000
# mean       3.795043
# std        2.105710
# min        1.129600
# 25%        2.100175
# 50%        3.207450
# 75%        5.188425
# max       12.126500
# Name: dis, dtype: float64

# %%
X_boston.shape
# Out:
# (506,)

# %%
rss_list = []
plt.figure(figsize=(10, 6))
X_range = np.linspace(X_boston.min(), X_boston.max(), 506).reshape(-1, 1)

colors = plt.cm.viridis(np.linspace(0, 1, 10))  # Smooth color map

for i, degree in enumerate(range(1, 11)):
    poly_ = PolynomialFeatures(degree=degree, include_bias=False)
    X_poly = poly_.fit_transform(X_boston.values.reshape(-1, 1))
    
    model = LinearRegression().fit(X_poly, y_boston)
    y_pred_train = model.predict(X_poly)
    rss = np.sum((y_boston - y_pred_train) ** 2)
    rss_list.append(rss)

    x_range_poly = poly_.transform(X_range)
    y_range_pred = model.predict(x_range_poly)

    plt.plot(X_range, y_range_pred, color=colors[i], linewidth=2, label=f'Degree {degree}')

# Plot original data last so it sits behind the lines
plt.scatter(X_boston, y_boston, color='black', alpha=0.5, label='Actual Data')

plt.xlabel('dis (Distance to Employment Centers)')
plt.ylabel('nox (NOx Concentration)')
plt.title('Polynomial Regression Fits (Degrees 1–10)')
plt.legend(loc='upper right', ncol=2)
plt.grid(True)
plt.tight_layout()
plt.show()

# Print RSS
for degree, rss in enumerate(rss_list, start=1):
    print(f"Degree {degree}: RSS = {rss:.4f}")
# Out:
# Degree 1: RSS = 2.7686
# Degree 2: RSS = 2.0353
# Degree 3: RSS = 1.9341
# Degree 4: RSS = 1.9330
# Degree 5: RSS = 1.9153
# Degree 6: RSS = 1.8783
# Degree 7: RSS = 1.8495
# Degree 8: RSS = 1.8356
# Degree 9: RSS = 1.8333
# Degree 10: RSS = 1.8383

# %%
plt.figure(figsize=(8, 5))
plt.plot(range(1, 11), rss_list, marker='o')
plt.xlabel("Polynomial Degree")
plt.ylabel("Residual Sum of Squares (RSS)")
plt.title("RSS vs Polynomial Degree")
plt.grid(True)
plt.show()

# %%
cv_errors = []

for degree in range(1, 11):
    poly = PolynomialFeatures(degree=degree, include_bias=False)
    X_poly = poly.fit_transform(X_boston.values.reshape(-1, 1))
    model = LinearRegression()
    
    # Use negative MSE (sklearn convention)
    scores = cross_val_score(model, X_poly, y_boston, cv=10, scoring='neg_mean_squared_error')
    mean_cv_mse = -scores.mean()
    cv_errors.append(mean_cv_mse)

# Find the degree with the lowest CV error
best_degree = np.argmin(cv_errors) + 1  # +1 since index starts at 0

print("Cross-validation MSE for each degree:")
for i, err in enumerate(cv_errors, start=1):
    print(f"Degree {i}: CV MSE = {err:.4f}")

print(f"\nOptimal degree based on CV: {best_degree}")
# Out:
# Cross-validation MSE for each degree:
# Degree 1: CV MSE = 0.0061
# Degree 2: CV MSE = 0.0044
# Degree 3: CV MSE = 0.0042
# Degree 4: CV MSE = 0.0057
# Degree 5: CV MSE = 0.0135
# Degree 6: CV MSE = 0.1057
# Degree 7: CV MSE = 0.1995
# Degree 8: CV MSE = 1.5326
# Degree 9: CV MSE = 0.6397
# Degree 10: CV MSE = 41.3163
#
# Optimal degree based on CV: 3

# %% [markdown]
# ## d)

# %%
from ISLP.models import bs


# Step 1: Convert 1D array and create spline basis matrix
X_vals = X_boston.values.ravel()
X_bs = np.vstack(bs(X_vals, df=4))

# Step 2: Fit the model
model = LinearRegression().fit(X_bs, y_boston)

# Step 3: Predict on smooth x-range
X_range = np.linspace(X_vals.min(), X_vals.max(), 300)
X_range_bs = np.vstack(bs(X_range, df=4))
y_pred = model.predict(X_range_bs)

# Step 4: Plot
plt.figure(figsize=(8, 6))
plt.scatter(X_boston, y_boston, color='gray', alpha=0.5, label='Actual Data')
plt.plot(X_range, y_pred, color='red', linewidth=2, label='Spline Fit (df=4)')
plt.xlabel('dis')
plt.ylabel('nox')
plt.title('Regression Spline Fit using bs() with df=4')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 6
#       4 # Step 1: Convert 1D array and create spline basis matrix
#       5 X_vals = X_boston.values.ravel()
# ----> 6 X_bs = np.vstack(bs(X_vals, df=4))
#       8 # Step 2: Fit the model
#       9 model = LinearRegression().fit(X_bs, y_boston)
#
# File ~/miniconda3/envs/env-statistic/lib/python3.9/site-packages/numpy/core/shape_base.py:289, in vstack(tup, dtype, casting)
#     287 if not isinstance(arrs, list):
#     288     arrs = [arrs]
# --> 289 return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 1, the array at index 0 has size 506 and the array at index 1 has size 1
