# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Exercice 8

# %% [markdown]
# **(a)**

# %%
# Calling the path of the data
path = "/content/drive/MyDrive/Math-448/ALL CSV FILES - 2nd Edition/College.csv"

# %%
college = pd.read_csv(path)

# %%
college.head()
# Out:
#                      Unnamed: 0 Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
college.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 777 entries, 0 to 776
# Data columns (total 19 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   777 non-null    object
#  1   Private      777 non-null    object
#  2   Apps         777 non-null    int64
#  3   Accept       777 non-null    int64
#  4   Enroll       777 non-null    int64
#  5   Top10perc    777 non-null    int64
#  6   Top25perc    777 non-null    int64
#  7   F.Undergrad  777 non-null    int64
#  8   P.Undergrad  777 non-null    int64
#  9   Outstate     777 non-null    int64
#  10  Room.Board   777 non-null    int64
#  11  Books        777 non-null    int64
#  12  Personal     777 non-null    int64
#  13  PhD          777 non-null    int64
#  14  Terminal     777 non-null    int64
#  15  S.F.Ratio    777 non-null    float64
#  16  perc.alumni  777 non-null    int64
#  17  Expend       777 non-null    int64
#  18  Grad.Rate    777 non-null    int64
# ...

# %% [markdown]
# **(b)**

# %%
# prompt: Using dataframe college: college3 = college.rename({'Unnamed: 0': 'College'},
# axis=1)

# Rename the 'Unnamed: 0' column to 'College'
college3 = college.rename({'Unnamed: 0': 'College'}, axis=1)

# %%
college3.head()
# Out:
#                         College Private  Apps  Accept  Enroll  Top10perc  \
# 0  Abilene Christian University     Yes  1660    1232     721         23
# 1            Adelphi University     Yes  2186    1924     512         16
# 2                Adrian College     Yes  1428    1097     336         22
# 3           Agnes Scott College     Yes   417     349     137         60
# 4     Alaska Pacific University     Yes   193     146      55         16
#
#    Top25perc  F.Undergrad  P.Undergrad  Outstate  Room.Board  Books  Personal  \
# 0         52         2885          537      7440        3300    450      2200
# 1         29         2683         1227     12280        6450    750      1500
# 2         50         1036           99     11250        3750    400      1165
# 3         89          510           63     12960        5450    450       875
# 4         44          249          869      7560        4120    800      1500
#
# ...

# %%
# Set 'College' to index
college3 = college3.set_index('College')

# %%
college3.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %%
college = college3

# %%
college.head()
# Out:
#                              Private  Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University     Yes  1660    1232     721         23
# Adelphi University               Yes  2186    1924     512         16
# Adrian College                   Yes  1428    1097     336         22
# Agnes Scott College              Yes   417     349     137         60
# Alaska Pacific University        Yes   193     146      55         16
#
#                               Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# College
# Abilene Christian University         52         2885          537      7440
# Adelphi University                   29         2683         1227     12280
# Adrian College                       50         1036           99     11250
# Agnes Scott College                  89          510           63     12960
# Alaska Pacific University            44          249          869      7560
#
# ...

# %% [markdown]
# **(c)**

# %%
# Use describe function to get summary
college.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %%
# scatter
columns = ['Top10perc', 'Apps', 'Enroll']
pd.plotting.scatter_matrix(college[columns], figsize=(10, 10))
plt.show()

# %%
from scipy.stats import skew

# Calculate skewness for each variable
print("Skewness of Top10perc:", college["Top10perc"].skew())
print("Skewness of Apps:", college["Apps"].skew())
print("Skewness of Enroll:", college["Enroll"].skew())
# Out:
# Skewness of Top10perc: 1.4132167808936722
# Skewness of Apps: 3.7237499684473048
# Skewness of Enroll: 2.6904646541429256

# %%
# boxplots of Outstate versus Private.
college.boxplot(column='Outstate', by='Private', figsize=(8, 6))
plt.title('Outstate vs. Private')
plt.suptitle('')  # Remove the automatic title generated by boxplot
plt.ylabel('Outstate')
plt.show()

# %%
# Create the 'Elite' column based on 'Top10perc'
college['Elite'] = pd.cut(college['Top10perc'], bins=[0, 50, 100], labels=['No', 'Yes'])

# %%
# Checking how many elite universities are
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
# boxplots of Outstate versus Elite.
college.boxplot(column='Outstate', by='Elite', figsize=(8, 6))
plt.title('Outstate vs. Elite')
plt.suptitle('')  # Remove the automatic title generated by boxplot
plt.ylabel('Outstate')
plt.show()

# %%
college['Elite'].value_counts()
# Out:
# Elite
# No     699
# Yes     78
# Name: count, dtype: int64

# %%
college.hist(column='Outstate', by='Elite', figsize=(8, 6))
# Out:
# <ipython-input-28-e550c074e6e4>:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   college.hist(column='Outstate', by='Elite', figsize=(8, 6));

# %%
college
# Out:
#                                Private   Apps  Accept  Enroll  Top10perc  \
# College
# Abilene Christian University       Yes   1660    1232     721         23
# Adelphi University                 Yes   2186    1924     512         16
# Adrian College                     Yes   1428    1097     336         22
# Agnes Scott College                Yes    417     349     137         60
# Alaska Pacific University          Yes    193     146      55         16
# ...                                ...    ...     ...     ...        ...
# Worcester State College             No   2197    1515     543          4
# Xavier University                  Yes   1959    1805     695         24
# Xavier University of Louisiana     Yes   2097    1915     695         34
# Yale University                    Yes  10705    2453    1317         95
# York College of Pennsylvania       Yes   2989    1855     691         28
#
#                                 Top25perc  F.Undergrad  P.Undergrad  Outstate  \
# ...

# %%
# @title Private vs Enroll

from matplotlib import pyplot as plt
import seaborn as sns
figsize = (12, 1.2 * len(college['Private'].unique()))
plt.figure(figsize=figsize)
sns.violinplot(college, x='Enroll', y='Private', inner='box', palette='Dark2')
sns.despine(top=True, right=True, bottom=True, left=True)
# Out:
# <ipython-input-31-4ba8397f1cda>:7: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(college, x='Enroll', y='Private', inner='box', palette='Dark2')

# %% [markdown]
# # Exercice 10

# %%
#!pip install ISLP

# %%
from ISLP import load_data
from ISLP.models import (ModelSpec as MS,
                         summarize,
                         poly)

# %% [markdown]
# **(A) To begin, load in the Boston data set, which is part of the ISLP
# library**

# %%
# loading Boston data
boston = load_data('Boston')

# %%
boston = pd.DataFrame(boston)

# %% [markdown]
# **(B) How many rows are in this data set? How many columns? What
# do the rows and columns represent?**
# * Rows : 506
# * Cols: 13
# * Rows represent the observation or instance in the dataset
# * Cols represent predictors of the rows

# %%
# Checking the shape of the data
boston.shape
# Out:
# (506, 13)

# %%
boston.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#    lstat  medv
# 0   4.98  24.0
# 1   9.14  21.6
# 2   4.03  34.7
# 3   2.94  33.4
# 4   5.33  36.2

# %%
boston.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio       lstat  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534   12.653063
# ...

# %% [markdown]
# **(c) Make some pairwise scatterplots of the predictors (columns) in
# this data set. Describe your fndings**

# %%
cols = ['crim', 'age', 'medv']

# %%
pd.plotting.scatter_matrix(boston[cols], figsize=(10, 10))
plt.show()

# %% [markdown]
# Description of Finding:
#
#
# *  In the figure above, I am interested in the relationship of this features crim, age, and medv. However, I don't see any positive relationships between them.
# *   For instance medv vs age, there is no relation because the data scatter and ther is no trends.

# %%
# Calculate skewness for each variable
print("Skewness of Crim:", boston["crim"].skew())
print("Skewness of Age:", boston["age"].skew())
print("Skewness of Medv:", boston["medv"].skew())
# Out:
# Skewness of Crim: 5.223148798243851
# Skewness of Age: -0.5989626398812962
# Skewness of Medv: 1.1080984082549072

# %% [markdown]
# **(D)Are any of the predictors associated with per capita crime rate?
# If so, explain the relationship**
#
# * The heatmap highlights the predictors most strongly associated with crime rates, including rad, tax, and lstat. Key contributing factors appear to be poverty and limited resources, which likely play a significant role in influencing crime levels.

# %%
correlations = boston.corr()['crim'].sort_values( ascending=False)

# %%
correlations
# Out:
# crim       1.000000
# rad        0.625505
# tax        0.582764
# lstat      0.455621
# nox        0.420972
# indus      0.406583
# age        0.352734
# ptratio    0.289946
# chas      -0.055892
# zn        -0.200469
# rm        -0.219247
# dis       -0.379670
# medv      -0.388305
# Name: crim, dtype: float64

# %%
# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlations.to_frame().T, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# **(e) Do any of the suburbs of Boston appear to have particularly
# high crime rates? Tax rates? Pupil-teacher ratios? Comment on
# the range of each predictor**

# %%
import seaborn as sns

plt.figure(figsize=(10, 10))
sns.boxplot(data=boston[['crim', 'tax', 'ptratio']])
plt.title('Boxplots of Crime, Tax, and Pupil-Teacher Ratio')
plt.ylabel('Value')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create histograms
fig, axes = plt.subplots(1, 3, figsize=(15, 5))

sns.histplot(boston["crim"], bins=30, kde=True, ax=axes[0])
axes[0].set_title("Crime Rate Distribution")

sns.histplot(boston["tax"], bins=30, kde=True, ax=axes[1])
axes[1].set_title("Tax Rate Distribution")

sns.histplot(boston["ptratio"], bins=30, kde=True, ax=axes[2])
axes[2].set_title("Pupil-Teacher Ratio Distribution")

plt.tight_layout()
plt.show()

# %% [markdown]
# **(f) How many of the suburbs in this data set bound the Charles
# river?**
# * The suburbs in the data set bound the charles are 35.
# * The suburbs in the data does not set bound the charles are 471

# %%
boston['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %% [markdown]
# **(g) What is the median pupil-teacher ratio among the towns in this
# data set?**
# * The median pupil-teacher ratio among the towns is 19.05

# %%
boston['ptratio'].median()
# Out:
# 19.05

# %% [markdown]
# **(h) Which suburb of Boston has lowest median value of owneroccupied homes? What are the values of the other predictors
# for that suburb, and how do those values compare to the overall
# ranges for those predictors? Comment on your fndings.**
# 1. The suburb of Boston with the lowest medv is 398 index
# 2. I used describe() function to summarize the suburb of boston of the medv predictors, check the comparison at the bottom.

# %%
# Minimum the medv
min_medv_index = boston['medv'].idxmin()
print(f"min_medv_index: {min_medv_index}")
# Out:
# min_medv_index: 398

# %%
boston['medv']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: medv, Length: 506, dtype: float64

# %%
boston['medv'].describe()
# Out:
# count    506.000000
# mean      22.532806
# std        9.197104
# min        5.000000
# 25%       17.025000
# 50%       21.200000
# 75%       25.000000
# max       50.000000
# Name: medv, dtype: float64

# %% [markdown]
# **(i) In this data set, how many of the suburbs average more than
# seven rooms per dwelling? More than eight rooms per dwelling?
# Comment on the suburbs that average more than eight rooms
# per dwelling.**
# 1. The suburbs average more than 7 rooms = 64
# 2. The suburbs average more than 8 rooms = 13

# %%
rm_7 = boston[boston['rm'] > 7]
rm_8 = boston[boston['rm'] > 8]
len(rm_7), len(rm_8)
# Out:
# (64, 13)

# %%
# Suburbs average more than 8 rooms per dwelling
rm_8
# Out:
#         crim    zn  indus  chas     nox     rm   age     dis  rad  tax  \
# 97   0.12083   0.0   2.89     0  0.4450  8.069  76.0  3.4952    2  276
# 163  1.51902   0.0  19.58     1  0.6050  8.375  93.9  2.1620    5  403
# 204  0.02009  95.0   2.68     0  0.4161  8.034  31.9  5.1180    4  224
# 224  0.31533   0.0   6.20     0  0.5040  8.266  78.3  2.8944    8  307
# 225  0.52693   0.0   6.20     0  0.5040  8.725  83.0  2.8944    8  307
# 226  0.38214   0.0   6.20     0  0.5040  8.040  86.5  3.2157    8  307
# 232  0.57529   0.0   6.20     0  0.5070  8.337  73.3  3.8384    8  307
# 233  0.33147   0.0   6.20     0  0.5070  8.247  70.4  3.6519    8  307
# 253  0.36894  22.0   5.86     0  0.4310  8.259   8.4  8.9067    7  330
# 257  0.61154  20.0   3.97     0  0.6470  8.704  86.9  1.8010    5  264
# 262  0.52014  20.0   3.97     0  0.6470  8.398  91.5  2.2885    5  264
# 267  0.57834  20.0   3.97     0  0.5750  8.297  67.0  2.4216    5  264
# ...
